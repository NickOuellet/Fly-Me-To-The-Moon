# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
import lxml

# %% [markdown]
# ## Meeting Plan for Nicolas Ouellet and Benedicte Knudson:
# We colaborated over Zoom and in person **one** times and used a shared Github Repository that can be found [here](https://github.com/NickOuellet/Fly-Me-To-The-Moon). <br />
# We met:
# 10/11: <br />
# 5-7pm

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
r = requests.get("https://www.spaceweatherlive.com/en/solar-activity/top-50-solar-flares.html",timeout=10,headers=headers)
r.status_code
# Out:
# 200

# %%
text_response = r.content #https://stackoverflow.com/questions/52389692/beautifulsoup-and-prettify-function
soup = BeautifulSoup(text_response, "html.parser")
html = soup.prettify()
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Top 50 solar flares | Solar activity | SpaceWeatherLive.com
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
#   <meta content="On this page you will find an overview of the strongest solar flares since June 1996 together with links to more information in our archive and a v..." name="description"/>
#   <meta content="SpaceWeatherLive, Live, Aurora, Auroral activity, Aurora Australis, Aurora Borealis, northern lights, Solar wind, Kp-index, Space Weather, Space Weather Updates, Aurora forecast, Space Weather Alerts, Solar activity, Solar flares, Sunspots, Aurora alert, Auroral activity, The Sun, SDO, STEREO, EPAM, DSCOVR" name="keywords"/>
#   <!-- Facebook meta -->
#   <meta content="https://spaceweatherlive.com/en/solar-activity/top-50-solar-flares.html" property="og:url"/>
# ...

# %%
table = html.find("table") #find the table in the HTML

# %%
solar_flare_df = pd.read_html(html) #multiple tables rn, need to FIXME

# %%
solfla_df = solar_flare_df[0] #works when we just select the first table

# %%
solfla_df.columns = ["rank", "x_classification", "date", "region", "start_time", "maximum_time", "end_time", "movie"] #rename columns to be more descriptive

# %%
solfla_df
# Out:
#     rank x_classification        date  region start_time maximum_time  \
# 0      1             X28+  2003/11/04     486      19:29        19:53
# 1      2             X20+  2001/04/02    9393      21:32        21:51
# 2      3           X17.2+  2003/10/28     486      09:51        11:10
# 3      4             X17+  2005/09/07     808      17:17        17:40
# 4      5            X14.4  2001/04/15    9415      13:19        13:50
# 5      6              X10  2003/10/29     486      20:37        20:49
# 6      7             X9.4  1997/11/06    8100      11:49        11:55
# 7      8             X9.3  2017/09/06    2673      11:53        12:02
# 8      9               X9  2006/12/05     930      10:18        10:35
# 9     10             X8.3  2003/11/02     486      17:03        17:25
# 10    11             X8.2  2017/09/10    2673      15:35        16:06
# 11    12             X7.1  2005/01/20     720      06:36        07:01
# ...
