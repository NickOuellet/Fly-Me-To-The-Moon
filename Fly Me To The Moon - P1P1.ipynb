# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
import lxml
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## Meeting Plan for Nicolas Ouellet and Benedicte Knudson:
# We colaborated over Zoom and in person **four** times and used a shared Github Repository that can be found [here](https://github.com/NickOuellet/Fly-Me-To-The-Moon). <br />
# We met: <br />
# 10/11: 5pm-7pm <br />
# 10/20: 10am-12pm <br />
# 10/21: 7-11pm <br />
# 10/25: 7-10pm <br />
#
# 11/9: 8-10:30<br />
# 11/10: 8-10<br />
#
# ___

# %% [markdown]
# ## Step 1 - Scrape SpaceWeatherLive.com

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
r = requests.get("https://www.spaceweatherlive.com/en/solar-activity/top-50-solar-flares.html",timeout=10,headers=headers)
r.status_code
# Out:
# 200

# %%
text_response = r.content #https://stackoverflow.com/questions/52389692/beautifulsoup-and-prettify-function
soup = BeautifulSoup(text_response,"html.parser")

# %%
table = soup.findAll("table") #find the table in the HTML

# %%
solar_flare_df = pd.read_html(str(table))

# %%
solfla_df = solar_flare_df[0]#works when we just select the first table

# %%
solfla_df.columns = ["rank", "x_class", "date", "region", "start_time", "maximum_time", "end_time", "movie"] #rename columns to be more descriptive

# %%
solfla_df
# Out:
#     rank x_class        date  region start_time maximum_time end_time  \
# 0      1    X28+  2003/11/04     486      19:29        19:53    20:06
# 1      2    X20+  2001/04/02    9393      21:32        21:51    22:03
# 2      3  X17.2+  2003/10/28     486      09:51        11:10    11:24
# 3      4    X17+  2005/09/07     808      17:17        17:40    18:03
# 4      5   X14.4  2001/04/15    9415      13:19        13:50    13:55
# 5      6     X10  2003/10/29     486      20:37        20:49    21:01
# 6      7    X9.4  1997/11/06    8100      11:49        11:55    12:01
# 7      8    X9.3  2017/09/06    2673      11:53        12:02    12:10
# 8      9      X9  2006/12/05     930      10:18        10:35    10:45
# 9     10    X8.3  2003/11/02     486      17:03        17:25    17:39
# 10    11    X8.2  2017/09/10    2673      15:35        16:06    16:31
# 11    12    X7.1  2005/01/20     720      06:36        07:01    07:26
# 12    13    X6.9  2011/08/09    1263      07:48        08:05    08:08
# 13    14    X6.5  2006/12/06     930      18:29        18:47    19:00
# 14    15    X6.2  2005/09/09     808      19:13        20:04    20:36
# 15    16    X6.2  2001/12/13    9733      14:20        14:30    14:35
# 16    17    X5.7  2000/07/14    9077      10:03        10:24    10:43
# 17    18    X5.6  2001/04/06    9415      19:10        19:21    19:31
# 18    19    X5.4  2012/03/07    1429      00:02        00:24    00:40
# 19    20    X5.4  2005/09/08     808      20:52        21:06    21:17
# 20    21    X5.4  2003/10/23     486      08:19        08:35    08:49
# 21    22    X5.3  2001/08/25    9591      16:23        16:45    17:04
# 22    23    X4.9  2014/02/25    1990      00:39        00:49    01:03
# 23    24    X4.9  1998/08/18    8307      22:10        22:19    22:28
# 24    25    X4.8  2002/07/23      39      00:18        00:35    00:47
# 25    26      X4  2000/11/26    9236      16:34        16:48    16:56
# 26    27    X3.9  2003/11/03     488      09:43        09:55    10:19
# 27    28    X3.9  1998/08/19    8307      21:35        21:45    21:50
# 28    29    X3.8  2005/01/17     720      06:59        09:52    10:07
# 29    30    X3.7  1998/11/22    8384      06:30        06:42    06:49
# 30    31    X3.6  2005/09/09     808      09:42        09:59    10:08
# 31    32    X3.6  2004/07/16     649      13:49        13:55    14:01
# 32    33    X3.6  2003/05/28     365      00:17        00:27    00:39
# 33    34    X3.4  2006/12/13     930      02:14        02:40    02:57
# 34    35    X3.4  2001/12/28    9767      20:02        20:45    21:32
# 35    36    X3.3  2013/11/05    1890      22:07        22:12    22:15
# 36    37    X3.3  2002/07/20      39      21:04        21:30    21:54
# 37    38    X3.3  1998/11/28    8395      04:54        05:52    06:13
# 38    39    X3.2  2013/05/14    1748      00:00        01:11    01:20
# 39    40    X3.1  2014/10/24    2192      21:07        21:41    22:13
# 40    41    X3.1  2002/08/24      69      00:49        01:12    01:31
# 41    42      X3  2002/07/15      30      19:59        20:08    20:14
# 42    43    X2.8  2013/05/13    1748      15:48        16:05    16:16
# 43    44    X2.8  2001/12/11    9733      07:58        08:08    08:14
# 44    45    X2.8  1998/08/18    8307      08:14        08:24    08:32
# 45    46    X2.7  2015/05/05    2339      22:05        22:11    22:15
# 46    47    X2.7  2003/11/03     488      01:09        01:30    01:45
# 47    48    X2.7  1998/05/06    8210      07:58        08:09    08:20
# 48    49    X2.6  2005/01/15     720      22:25        23:02    23:31
# 49    50    X2.6  2001/09/24    9632      09:32        10:38    11:09
#
#                 movie
# 0   MovieView archive
# 1   MovieView archive
# 2   MovieView archive
# 3   MovieView archive
# 4   MovieView archive
# 5   MovieView archive
# 6   MovieView archive
# 7   MovieView archive
# 8   MovieView archive
# 9   MovieView archive
# 10  MovieView archive
# 11  MovieView archive
# 12  MovieView archive
# 13  MovieView archive
# 14  MovieView archive
# 15  MovieView archive
# 16  MovieView archive
# 17  MovieView archive
# 18  MovieView archive
# 19  MovieView archive
# 20  MovieView archive
# 21  MovieView archive
# 22  MovieView archive
# 23       View archive
# 24  MovieView archive
# 25  MovieView archive
# 26  MovieView archive
# 27       View archive
# 28  MovieView archive
# 29  MovieView archive
# 30  MovieView archive
# 31  MovieView archive
# 32  MovieView archive
# 33  MovieView archive
# 34  MovieView archive
# 35  MovieView archive
# 36  MovieView archive
# 37  MovieView archive
# 38  MovieView archive
# 39  MovieView archive
# 40  MovieView archive
# 41  MovieView archive
# 42  MovieView archive
# 43  MovieView archive
# 44       View archive
# 45  MovieView archive
# 46  MovieView archive
# 47  MovieView archive
# 48  MovieView archive
# 49  MovieView archive

# %% [markdown]
# ___
# ## Step 2 - Tidy the Top 50 Solar Flare Data

# %%
solfla_df = solfla_df[["rank", "x_class", "date", "start_time", "maximum_time", "end_time","region"]]
solfla_df.head()
# Out:
#    rank x_class        date start_time maximum_time end_time  region
# 0     1    X28+  2003/11/04      19:29        19:53    20:06     486
# 1     2    X20+  2001/04/02      21:32        21:51    22:03    9393
# 2     3  X17.2+  2003/10/28      09:51        11:10    11:24     486
# 3     4    X17+  2005/09/07      17:17        17:40    18:03     808
# 4     5   X14.4  2001/04/15      13:19        13:50    13:55    9415

# %%
import datetime

# %%
solfla_df.loc[:,"start_time"] = pd.to_datetime(solfla_df.loc[:,"date"] + " " + solfla_df.loc[:,"start_time"])
solfla_df.loc[:,"maximum_time"] = pd.to_datetime(solfla_df.loc[:,"date"] + " " + solfla_df.loc[:,"maximum_time"])
solfla_df.loc[:,"end_time"] = pd.to_datetime(solfla_df.loc[:,"date"] + " " + solfla_df.loc[:,"end_time"])
# Out:
# /Users/nicolasouellet/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
solfla_df.drop(columns="date",inplace=True) #drop date table
solfla_df.rename(columns={"start_time":"start_datetime", "end_time":"end_datetime","maximum_time":"maximum_datetime"},inplace=True)
solfla_df.head()
# Out:
# /Users/nicolasouellet/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/nicolasouellet/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    rank x_class      start_datetime    maximum_datetime        end_datetime  \
# 0     1    X28+ 2003-11-04 19:29:00 2003-11-04 19:53:00 2003-11-04 20:06:00
# 1     2    X20+ 2001-04-02 21:32:00 2001-04-02 21:51:00 2001-04-02 22:03:00
# 2     3  X17.2+ 2003-10-28 09:51:00 2003-10-28 11:10:00 2003-10-28 11:24:00
# 3     4    X17+ 2005-09-07 17:17:00 2005-09-07 17:40:00 2005-09-07 18:03:00
# 4     5   X14.4 2001-04-15 13:19:00 2001-04-15 13:50:00 2001-04-15 13:55:00
#
#    region
# 0     486
# 1    9393
# 2     486
# 3     808
# 4    9415

# %%
def remove_plus(string):
  return re.sub("\+", "", string,1)

def make_float(string): #make all number values in rating into floats to make searching easier later
  rating = string[0]
  string = string[1:]
  new_float = float(string)
  return rating + str(new_float)

  
solfla_df["x_class"] = solfla_df["x_class"].apply(remove_plus)
solfla_df["x_class"] = solfla_df["x_class"].apply(make_float)
# Out:
# <ipython-input-58-649202996ea7>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solfla_df["x_class"] = solfla_df["x_class"].apply(remove_plus)
# <ipython-input-58-649202996ea7>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solfla_df["x_class"] = solfla_df["x_class"].apply(make_float)

# %%
solfla_df.dtypes
# Out:
# rank                         int64
# x_class                     object
# start_datetime      datetime64[ns]
# maximum_datetime    datetime64[ns]
# end_datetime        datetime64[ns]
# region                       int64
# dtype: object

# %%
solfla_df
# Out:
#     rank x_class      start_datetime    maximum_datetime        end_datetime  \
# 0      1   X28.0 2003-11-04 19:29:00 2003-11-04 19:53:00 2003-11-04 20:06:00
# 1      2   X20.0 2001-04-02 21:32:00 2001-04-02 21:51:00 2001-04-02 22:03:00
# 2      3   X17.2 2003-10-28 09:51:00 2003-10-28 11:10:00 2003-10-28 11:24:00
# 3      4   X17.0 2005-09-07 17:17:00 2005-09-07 17:40:00 2005-09-07 18:03:00
# 4      5   X14.4 2001-04-15 13:19:00 2001-04-15 13:50:00 2001-04-15 13:55:00
# 5      6   X10.0 2003-10-29 20:37:00 2003-10-29 20:49:00 2003-10-29 21:01:00
# 6      7    X9.4 1997-11-06 11:49:00 1997-11-06 11:55:00 1997-11-06 12:01:00
# 7      8    X9.3 2017-09-06 11:53:00 2017-09-06 12:02:00 2017-09-06 12:10:00
# 8      9    X9.0 2006-12-05 10:18:00 2006-12-05 10:35:00 2006-12-05 10:45:00
# 40    41    X3.1 2002-08-24 00:49:00 2002-08-24 01:12:00 2002-08-24 01:31:00
# 41    42    X3.0 2002-07-15 19:59:00 2002-07-15 20:08:00 2002-07-15 20:14:00
# 42    43    X2.8 2013-05-13 15:48:00 2013-05-13 16:05:00 2013-05-13 16:16:00
# 43    44    X2.8 2001-12-11 07:58:00 2001-12-11 08:08:00 2001-12-11 08:14:00
# 44    45    X2.8 1998-08-18 08:14:00 1998-08-18 08:24:00 1998-08-18 08:32:00
# 45    46    X2.7 2015-05-05 22:05:00 2015-05-05 22:11:00 2015-05-05 22:15:00
# 46    47    X2.7 2003-11-03 01:09:00 2003-11-03 01:30:00 2003-11-03 01:45:00
# 47    48    X2.7 1998-05-06 07:58:00 1998-05-06 08:09:00 1998-05-06 08:20:00
# 48    49    X2.6 2005-01-15 22:25:00 2005-01-15 23:02:00 2005-01-15 23:31:00
# 49    50    X2.6 2001-09-24 09:32:00 2001-09-24 10:38:00 2001-09-24 11:09:00
#
#     region
# 0      486
# 1     9393
# 2      486
# 3      808
# 4     9415
# 5      486
# 6     8100
# 7     2673
# 8      930
# 9      486
# 10    2673
# 11     720
# 12    1263
# 13     930
# 14     808
# 15    9733
# 16    9077
# 17    9415
# 18    1429
# 19     808
# 20     486
# 21    9591
# 22    1990
# 23    8307
# 24      39
# 25    9236
# 26     488
# 27    8307
# 28     720
# 29    8384
# 30     808
# 31     649
# 32     365
# 33     930
# 34    9767
# 35    1890
# 36      39
# 37    8395
# 38    1748
# 39    2192
# 40      69
# 41      30
# 42    1748
# 43    9733
# 44    8307
# 45    2339
# 46     488
# 47    8210
# 48     720
# 49    9632

# %% [markdown]
# ___
# ## Step 3 - Scrape the NASA Data

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
r = requests.get("https://cdaw.gsfc.nasa.gov/CME_list/radio/waves_type2.html",timeout=10,headers=headers)
r.status_code
# Out:
# 200

# %%
text_response = r.content #https://stackoverflow.com/questions/52389692/beautifulsoup-and-prettify-function
soup = BeautifulSoup(text_response,"html.parser")
table = soup.get_text()
split_table = table.splitlines()
split_table = split_table[15:]
split_table = split_table[0:len(split_table)-2] #clean up table by removing top and bottom portion

# %%
nasa_df = pd.DataFrame( #create empty DF 
    columns = ["start_date","start_time","end_date","end_time","start_freq","end_freq","location","region","xray_importance","cme_date","cme_time","central_pos_angle","cpa_width","cme_speed","PHTX" ]
    )
for i,v in enumerate(split_table): 
  row_vals = re.findall(r"\S+",v)
  nasa_df.loc[i] = row_vals[0:15] #assign values for each row from list after splitting string into a list var, also drop 16th entry because sometimes it is useless notation

# %%
naas_df = nasa_df.reindex(columns=["cme_date","cme_time","central_pos_angle","end_date","end_freq","end_time","location","region","xray_importance","cme_speed","start_date", "start_time", "start_freq","cpa_width","PHTX"])
nasa_df
# Out:
#      start_date start_time end_date end_time start_freq end_freq location  \
# 0    1997/04/01      14:00    04/01    14:15       8000     4000   S25E16
# 1    1997/04/07      14:30    04/07    17:30      11000     1000   S28E19
# 2    1997/05/12      05:15    05/14    16:00      12000       80   N21W08
# 3    1997/05/21      20:20    05/21    22:00       5000      500   N05W12
# 4    1997/09/23      21:53    09/23    22:16       6000     2000   S29E25
# ..          ...        ...      ...      ...        ...      ...      ...
# 517  2017/09/17      11:45    09/17    12:35      16000      900  S08E170
# 518  2017/10/18      05:48    10/18    12:40      16000      400  S06E123
# 519  2019/05/03      23:52    05/04    00:16      13000     2300   N12E82
# 520  2020/11/29      13:07    11/29    15:23      14000      850   S23E89
# 521  2020/12/07      16:18    12/08    02:00      14000      160   S25W08
#
#     region xray_importance cme_date cme_time central_pos_angle cpa_width  \
# 0     8026            M1.3    04/01    15:18                74        79
# 1     8027            C6.8    04/07    14:27              Halo       360
# 2     8038            C1.3    05/12    05:30              Halo       360
# 3     8040            M1.3    05/21    21:00               263       165
# 4     8088            C1.4    09/23    22:02               133       155
# ..     ...             ...      ...      ...               ...       ...
# 517  -----            ----    09/17    12:00              Halo       360
# 518  -----            ----    10/18    08:00                85       146
# 519  12740            C1.0    05/03    23:24                90       113
# 520  -----            M4.4    11/29    13:25              Halo       360
# 521  12790            C7.4    12/07    16:24              Halo       360
#
#     cme_speed  PHTX
# 0         312  PHTX
# 1         878  PHTX
# 2         464  PHTX
# 3         296  PHTX
# 4         712  PHTX
# ..        ...   ...
# 517      1385  PHTX
# 518      1001  PHTX
# 519       692  PHTX
# 520      2077  ----
# 521      1407  ----
#
# [522 rows x 15 columns]

# %%
nasa_df.drop(columns=["PHTX"],inplace=True) #drop links column

# %%
nasa_df
# Out:
#      start_date start_time end_date end_time start_freq end_freq location  \
# 0    1997/04/01      14:00    04/01    14:15       8000     4000   S25E16
# 1    1997/04/07      14:30    04/07    17:30      11000     1000   S28E19
# 2    1997/05/12      05:15    05/14    16:00      12000       80   N21W08
# 3    1997/05/21      20:20    05/21    22:00       5000      500   N05W12
# 4    1997/09/23      21:53    09/23    22:16       6000     2000   S29E25
# ..          ...        ...      ...      ...        ...      ...      ...
# 517  2017/09/17      11:45    09/17    12:35      16000      900  S08E170
# 518  2017/10/18      05:48    10/18    12:40      16000      400  S06E123
# 519  2019/05/03      23:52    05/04    00:16      13000     2300   N12E82
# 520  2020/11/29      13:07    11/29    15:23      14000      850   S23E89
# 521  2020/12/07      16:18    12/08    02:00      14000      160   S25W08
#
#     region xray_importance cme_date cme_time central_pos_angle cpa_width  \
# 0     8026            M1.3    04/01    15:18                74        79
# 1     8027            C6.8    04/07    14:27              Halo       360
# 2     8038            C1.3    05/12    05:30              Halo       360
# 3     8040            M1.3    05/21    21:00               263       165
# 4     8088            C1.4    09/23    22:02               133       155
# ..     ...             ...      ...      ...               ...       ...
# 517  -----            ----    09/17    12:00              Halo       360
# 518  -----            ----    10/18    08:00                85       146
# 519  12740            C1.0    05/03    23:24                90       113
# 520  -----            M4.4    11/29    13:25              Halo       360
# 521  12790            C7.4    12/07    16:24              Halo       360
#
#     cme_speed
# 0         312
# 1         878
# 2         464
# 3         296
# 4         712
# ..        ...
# 517      1385
# 518      1001
# 519       692
# 520      2077
# 521      1407
#
# [522 rows x 14 columns]

# %% [markdown]
# ___
# ## Step 4 - Tidy the Nasa Data

# %% [markdown]
# **Replace all empty values with NaNs**

# %%
nasa_df.region.replace("-----", np.nan,inplace=True)
nasa_df.xray_importance.replace("----", np.nan,inplace=True)
nasa_df.cme_date.replace("--/--",np.nan, inplace=True)
nasa_df.cme_time.replace("--:--",np.nan,inplace=True)
nasa_df.central_pos_angle.replace("----", np.nan,inplace=True)
nasa_df.cpa_width.replace("----", np.nan,inplace=True)
nasa_df.cpa_width.replace("---", np.nan,inplace=True)
nasa_df.cpa_width.replace("360h", "360",inplace=True)
nasa_df.cme_speed.replace("----", np.nan,inplace=True)
nasa_df.start_freq.replace("????",np.nan,inplace=True)
nasa_df.end_freq.replace("????",np.nan,inplace=True)

# %% [markdown]
# **Replace all lower case "Back" values with upper case "BACK" in location column**

# %%
nasa_df.location.replace("Back","BACK",inplace=True)

# %% [markdown]
# **Replace all DSF values with FILA in region column**

# %%
nasa_df.region.replace("DSF","FILE",inplace=True)

# %% [markdown]
# **Create column to indicate HALO flare, then turn Halo entries into NaN.**<br/>
# Halo = 1 <br/>
# Non-Halo = 0

# %%
column_vals = []
for index,value in nasa_df["central_pos_angle"].iteritems():
  if value == "Halo":
    column_vals.append(True)
  else:
    column_vals.append(False)
nasa_df["is_halo"] = column_vals

# %%
nasa_df.central_pos_angle.replace("Halo", np.nan,inplace=True)

# %% [markdown]
# **Indicate which cpa_widths are lower bounds, make a new column with the info, then remove the non-numeric characters**

# %%
column_vals = []
for index,value in nasa_df["cpa_width"].iteritems():
  if pd.isnull(value) == True:
    column_vals.append(True)
  elif ">" in value:
        column_vals.append(False)
  else:
    column_vals.append(False)
nasa_df["lower_bound"] = column_vals

# %%
def remove_sign(str):
  if pd.isnull(str) == True:
    return str
  return re.sub(">","",str)

nasa_df["cpa_width"] = nasa_df["cpa_width"].apply(remove_sign)

# %% [markdown]
# **Reformat date columns and drop repetitive data**

# %%
nasa_df.replace("24:00","23:59",inplace=True)

# %%
for index,value in nasa_df["end_date"].iteritems():
  year = nasa_df.start_date.loc[index][0:4]
  nasa_df["end_date"].loc[index] = pd.to_datetime(year + "/" + nasa_df["end_date"].loc[index] + " " + nasa_df["end_time"].loc[index])

for index,value in nasa_df["cme_date"].iteritems():
  year = nasa_df.start_date.loc[index][0:4]
  if pd.isnull(nasa_df["cme_date"].loc[index]):
    pass
  else:
    nasa_df["cme_date"].loc[index] = pd.to_datetime(year + "/" + nasa_df["cme_date"].loc[index] + " " + nasa_df["cme_time"].loc[index])

nasa_df.loc[:,"start_date"] = pd.to_datetime(nasa_df.loc[:,"start_date"] + " " + nasa_df.loc[:,"start_time"])
nasa_df.loc[:,"end_date"] = pd.to_datetime(nasa_df.loc[:,"end_date"])
nasa_df.loc[:,"cme_date"] = pd.to_datetime(nasa_df.loc[:,"cme_date"])
# Out:
# /Users/nicolasouellet/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
nasa_df.rename(columns={"start_date":"start_datetime", "end_date":"end_datetime","cme_date":"cme_datetime"},inplace=True) #rename columns

# %%
nasa_df.drop(columns=["start_time","end_time","cme_time"],inplace=True) #drop unnessecary values

# %%
nasa_df.start_freq = nasa_df.start_freq.astype('float') #change all str types to float
nasa_df.end_freq = nasa_df.end_freq.astype('float')
nasa_df.central_pos_angle = nasa_df.central_pos_angle.astype('float')
nasa_df.cme_speed = nasa_df.cme_speed.astype('float')
nasa_df.cpa_width = nasa_df.cpa_width.astype('float')

# %% [markdown]
# **Adjust xray_importance column to have 0 after "." value for easier searching later**

# %%
nasa_df.dtypes
# Out:
# start_datetime       datetime64[ns]
# end_datetime         datetime64[ns]
# start_freq                  float64
# end_freq                    float64
# location                     object
# region                       object
# xray_importance              object
# cme_datetime         datetime64[ns]
# central_pos_angle           float64
# cpa_width                   float64
# cme_speed                   float64
# is_halo                        bool
# lower_bound                    bool
# dtype: object

# %%
nasa_df
# Out:
#          start_datetime        end_datetime  start_freq  end_freq location  \
# 0   1997-04-01 14:00:00 1997-04-01 14:15:00      8000.0    4000.0   S25E16
# 1   1997-04-07 14:30:00 1997-04-07 17:30:00     11000.0    1000.0   S28E19
# 2   1997-05-12 05:15:00 1997-05-14 16:00:00     12000.0      80.0   N21W08
# 3   1997-05-21 20:20:00 1997-05-21 22:00:00      5000.0     500.0   N05W12
# 4   1997-09-23 21:53:00 1997-09-23 22:16:00      6000.0    2000.0   S29E25
# ..                  ...                 ...         ...       ...      ...
# 517 2017-09-17 11:45:00 2017-09-17 12:35:00     16000.0     900.0  S08E170
# 518 2017-10-18 05:48:00 2017-10-18 12:40:00     16000.0     400.0  S06E123
# 519 2019-05-03 23:52:00 2019-05-04 00:16:00     13000.0    2300.0   N12E82
# 520 2020-11-29 13:07:00 2020-11-29 15:23:00     14000.0     850.0   S23E89
# 521 2020-12-07 16:18:00 2020-12-08 02:00:00     14000.0     160.0   S25W08
#
#     region xray_importance        cme_datetime  central_pos_angle  cpa_width  \
# 0     8026            M1.3 1997-04-01 15:18:00               74.0       79.0
# 1     8027            C6.8 1997-04-07 14:27:00                NaN      360.0
# 2     8038            C1.3 1997-05-12 05:30:00                NaN      360.0
# 3     8040            M1.3 1997-05-21 21:00:00              263.0      165.0
# 4     8088            C1.4 1997-09-23 22:02:00              133.0      155.0
# ..     ...             ...                 ...                ...        ...
# 517    NaN             NaN 2017-09-17 12:00:00                NaN      360.0
# 518    NaN             NaN 2017-10-18 08:00:00               85.0      146.0
# 519  12740            C1.0 2019-05-03 23:24:00               90.0      113.0
# 520    NaN            M4.4 2020-11-29 13:25:00                NaN      360.0
# 521  12790            C7.4 2020-12-07 16:24:00                NaN      360.0
#
#      cme_speed  is_halo  lower_bound
# 0        312.0    False        False
# 1        878.0     True        False
# 2        464.0     True        False
# 3        296.0    False        False
# 4        712.0    False        False
# ..         ...      ...          ...
# 517     1385.0     True        False
# 518     1001.0    False        False
# 519      692.0    False        False
# 520     2077.0     True        False
# 521     1407.0     True        False
#
# [522 rows x 13 columns]

# %% [markdown]
# ___

# %% [markdown]
# # Part 2 Analysis:

# %% [markdown]
# ## Question 1: Get Top 50 Nasa Solar Falres

# %%
nasa_df.head()
# Out:
#        start_datetime        end_datetime  start_freq  end_freq location  \
# 0 1997-04-01 14:00:00 1997-04-01 14:15:00      8000.0    4000.0   S25E16
# 1 1997-04-07 14:30:00 1997-04-07 17:30:00     11000.0    1000.0   S28E19
# 2 1997-05-12 05:15:00 1997-05-14 16:00:00     12000.0      80.0   N21W08
# 3 1997-05-21 20:20:00 1997-05-21 22:00:00      5000.0     500.0   N05W12
# 4 1997-09-23 21:53:00 1997-09-23 22:16:00      6000.0    2000.0   S29E25
#
#   region xray_importance        cme_datetime  central_pos_angle  cpa_width  \
# 0   8026            M1.3 1997-04-01 15:18:00               74.0       79.0
# 1   8027            C6.8 1997-04-07 14:27:00                NaN      360.0
# 2   8038            C1.3 1997-05-12 05:30:00                NaN      360.0
# 3   8040            M1.3 1997-05-21 21:00:00              263.0      165.0
# 4   8088            C1.4 1997-09-23 22:02:00              133.0      155.0
#
#    cme_speed  is_halo  lower_bound
# 0      312.0    False        False
# 1      878.0     True        False
# 2      464.0     True        False
# 3      296.0    False        False
# 4      712.0    False        False

# %%
solfla_df.head()
# Out:
#    rank x_class      start_datetime    maximum_datetime        end_datetime  \
# 0     1   X28.0 2003-11-04 19:29:00 2003-11-04 19:53:00 2003-11-04 20:06:00
# 1     2   X20.0 2001-04-02 21:32:00 2001-04-02 21:51:00 2001-04-02 22:03:00
# 2     3   X17.2 2003-10-28 09:51:00 2003-10-28 11:10:00 2003-10-28 11:24:00
# 3     4   X17.0 2005-09-07 17:17:00 2005-09-07 17:40:00 2005-09-07 18:03:00
# 4     5   X14.4 2001-04-15 13:19:00 2001-04-15 13:50:00 2001-04-15 13:55:00
#
#    region
# 0     486
# 1    9393
# 2     486
# 3     808
# 4    9415

# %% [markdown]
# **We will first gather the entries for the nasa column that are rated of "X" importance.**

# %%
flare_lst = []

for index,value in nasa_df.iterrows():
    if pd.isnull(value["xray_importance"]) == False and "X" in value["xray_importance"]:
       flare_lst.append(value)

# %% [markdown]
# **We will then sort the values based on their numerical compenenet by stripping the "X" from the value.**

# %%
flare_lst.sort(key=lambda x: float(x[6][1:]),reverse=True) #all X value flares sorted from largest to smallest with dates

# %% [markdown]
# **Finally, we create a new dataframe and only take the 50 strongest flares.**

# %%
NASAtop50_df = pd.DataFrame(
    columns = ['start_datetime', 'end_datetime', 'start_freq', 'end_freq', 'location',
       'region', 'xray_importance', 'cme_datetime', 'central_pos_angle',
       'cpa_width', 'cme_speed', 'is_halo', 'lower_bound'],
    data = flare_lst[0:50]
)

# %%
NASAtop50_df.reset_index()
# Out:
#     index      start_datetime        end_datetime  start_freq  end_freq  \
# 0     240 2003-11-04 20:00:00 2003-11-04 23:59:00     10000.0     200.0
# 1     117 2001-04-02 22:05:00 2001-04-03 02:30:00     14000.0     250.0
# 2     233 2003-10-28 11:10:00 2003-10-29 23:59:00     14000.0      40.0
# 3     126 2001-04-15 14:05:00 2001-04-16 13:00:00     14000.0      40.0
# 4     234 2003-10-29 20:55:00 2003-10-29 23:59:00     11000.0     500.0
# 35   N15W05  10720            X2.6 2005-01-15 23:06:00                NaN
# 36   N09W49  10696            X2.5 2004-11-10 02:26:00                NaN
# 37   N20E18   9026            X2.3 2000-06-06 15:54:00                NaN
# 38   N22W07   9236            X2.3 2000-11-24 15:30:00                NaN
# 39   S23W09   9415            X2.3 2001-04-10 05:30:00                NaN
# 40   S20W12  11158            X2.2 2011-02-15 02:24:00                NaN
# 41   S14W33   8100            X2.1 1997-11-04 06:10:00                NaN
# 42   S13E47  10808            X2.1 2005-09-10 21:52:00                NaN
# 43   N14W18  11283            X2.1 2011-09-06 23:05:00                NaN
# 44   S06E69  11882            X2.1 2013-10-25 15:12:00                NaN
# 45   N20W05   9236            X2.0 2000-11-24 05:30:00                NaN
# 46   S19W43   9415            X2.0 2001-04-12 10:31:00                NaN
# 47   N09W17  10696            X2.0 2004-11-07 16:54:00                NaN
# 48   N15W25  10720            X2.0 2005-01-17 09:30:00                NaN
# 49   N20W23   9236            X1.9 2000-11-25 19:31:00                NaN
#
#     cpa_width  cme_speed  is_halo  lower_bound
# 0       360.0     2657.0     True        False
# 1       244.0     2505.0    False        False
# 2       360.0     2459.0     True        False
# 3       167.0     1199.0    False        False
# 4       360.0     2029.0     True        False
# 5       360.0     1556.0     True        False
# 6       360.0     1571.0     True        False
# 7         NaN        NaN    False         True
# 8       360.0     2598.0     True        False
# 9       360.0     3163.0     True        False
# 10      360.0      882.0     True        False
# 11      360.0     1610.0     True        False
# 12        NaN        NaN    False         True
# 13      360.0     2257.0     True        False
# 14      360.0     1674.0     True        False
# 15      360.0     1270.0     True        False
# 16      360.0     2684.0     True        False
# 17      360.0     1433.0     True        False
# 18      360.0     2147.0     True        False
# 19      360.0     2285.0     True        False
# 20      360.0      980.0     True        False
# 21      103.0     1420.0    False        False
# 22      360.0     2547.0     True        False
# 23      360.0     1366.0     True        False
# 24      360.0     2216.0     True        False
# 25      360.0     1774.0     True        False
# 26      360.0     1941.0     True        False
# 27      360.0     2625.0     True        False
# 28      360.0     1913.0     True        False
# 29      360.0     1850.0     True        False
# 30      190.0     1099.0    False        False
# 31       65.0      827.0    False        False
# 32      360.0      715.0     True        False
# 33       91.0      441.0    False        False
# 34      360.0     2402.0     True        False
# 35      360.0     2861.0     True        False
# 36      360.0     3387.0     True        False
# 37      360.0     1119.0     True        False
# 38      360.0     1245.0     True        False
# 39      360.0     2411.0     True        False
# 40      360.0      669.0     True        False
# 41      360.0      785.0     True        False
# 42      360.0     1893.0     True        False
# 43      360.0      575.0     True        False
# 44      360.0     1081.0     True        False
# 45      360.0     1289.0     True        False
# 46      360.0     1184.0     True        False
# 47      360.0     1759.0     True        False
# 48      360.0     2094.0     True        False
# 49      360.0      671.0     True        False

# %% [markdown]
# **The top 50 solar flares from Nasa don't exactly match the top 50 solar flares from SpaceWeatherLive.**
# ___

# %% [markdown]
# ## Question 2: Integration
# We are defining best matching rows by: <br/>
# 1. Check if the x_class matches within a tolereance of +/- 0.5<br/>
# 2. Check if the regions match<br/>
# 3. Check if the DD/MM/YYYY matches<br/>
#
#
# If all three are a match, we assign the row in the Nasa table with the rank in the SpaceWeatherLive table. We need to have some liency with the matching because sometimes the same flare has different measurements between tables. For example one flare has two different class ratings of X14.4 and X14.0, but they occur on the same date and in the same region so we assume that they are the same and chock the class rating up to recording error.

# %%
NASAtop50_df["Match"] = np.nan
for index, value in NASAtop50_df.iterrows():
    for index2, value2 in solfla_df.iterrows(): 
        if np.isclose(float(value["xray_importance"][1:]), float(value2["x_class"][1:]), atol=.5) == True: #CHECK 1
            if float(value["region"]) > 10000: #regions greater than 10000 in the nasa table correspond with the region in the spaceweatherlive table only if we subtract 10000 from the nasa region.
                rank = float(value["region"]) - 10000
            else:
                rank = float(value["region"])
            if rank == float(value2["region"]): #CHECK 2
                if value["start_datetime"].date() == value2["start_datetime"].date(): #CHECK 3
                    match = solfla_df.loc[index2, "rank"] #do this assign to avoid the "trying to assign a value on a copy of a table" error that is produced sometimes.
                    NASAtop50_df.loc[index, "Match"] = match

NASAtop50_df
# Out:
#          start_datetime        end_datetime  start_freq  end_freq location  \
# 240 2003-11-04 20:00:00 2003-11-04 23:59:00     10000.0     200.0   S19W83
# 117 2001-04-02 22:05:00 2001-04-03 02:30:00     14000.0     250.0   N19W72
# 233 2003-10-28 11:10:00 2003-10-29 23:59:00     14000.0      40.0   S16E08
# 126 2001-04-15 14:05:00 2001-04-16 13:00:00     14000.0      40.0   S20W85
# 234 2003-10-29 20:55:00 2003-10-29 23:59:00     11000.0     500.0   S15W02
# 8   1997-11-06 12:20:00 1997-11-07 08:30:00     14000.0     100.0   S18W63
# 514 2017-09-06 12:05:00 2017-09-07 08:00:00     16000.0      70.0   S08W33
# 328 2006-12-05 10:50:00 2006-12-05 20:00:00     14000.0     250.0   S07E68
# 237 2003-11-02 17:30:00 2003-11-03 01:00:00     12000.0     250.0   S14W56
# 288 2005-01-20 07:15:00 2005-01-20 16:30:00     14000.0      25.0   N14W61
# 359 2011-08-09 08:20:00 2011-08-09 08:35:00     16000.0    4000.0   N17W69
# 331 2006-12-06 19:00:00 2006-12-08 23:59:00     16000.0      30.0   S05E64
# 317 2005-09-09 19:45:00 2005-09-09 22:00:00     10000.0      50.0   S12E67
# 82  2000-07-14 10:30:00 2000-07-15 14:30:00     14000.0      80.0   N22W07
# 121 2001-04-06 19:35:00 2001-04-07 01:50:00     14000.0     230.0   S21E31
# 375 2012-03-07 01:00:00 2012-03-08 19:00:00     16000.0      30.0   N17E27
# 135 2001-08-25 16:50:00 2001-08-25 23:00:00      8000.0     170.0   S17E34
# 443 2014-02-25 00:56:00 2014-02-25 11:28:00     14000.0     100.0   S12E82
# 193 2002-07-23 00:50:00 2002-07-23 04:00:00     11000.0     400.0   S13E72
# 104 2000-11-26 17:00:00 2000-11-26 17:15:00     14000.0    7000.0   N18W38
# 239 2003-11-03 10:00:00 2003-11-03 12:30:00      6000.0     400.0   N08W77
# 286 2005-01-17 10:00:00 2005-01-17 10:35:00      6100.0    1500.0   N15W25
# 240      360.0     2657.0     True        False    1.0
# 117      244.0     2505.0    False        False    2.0
# 233      360.0     2459.0     True        False    3.0
# 126      167.0     1199.0    False        False    5.0
# 234      360.0     2029.0     True        False    6.0
# 8        360.0     1556.0     True        False    7.0
# 514      360.0     1571.0     True        False    8.0
# 328        NaN        NaN    False         True    9.0
# 237      360.0     2598.0     True        False   10.0
# 288      360.0      882.0     True        False   12.0
# 359      360.0     1610.0     True        False   13.0
# 331        NaN        NaN    False         True   14.0
# 317      360.0     2257.0     True        False   15.0
# 82       360.0     1674.0     True        False   17.0
# 121      360.0     1270.0     True        False   18.0
# 375      360.0     2684.0     True        False   19.0
# 135      360.0     1433.0     True        False   22.0
# 443      360.0     2147.0     True        False   23.0
# 193      360.0     2285.0     True        False   25.0
# 104      360.0      980.0     True        False   26.0
# 239      103.0     1420.0    False        False   27.0
# 286      360.0     2547.0     True        False   29.0
# 222      360.0     1366.0     True        False   33.0
# 332      360.0     1774.0     True        False   34.0
# 192      360.0     1941.0     True        False   37.0
# 404      360.0     2625.0     True        False   39.0
# 201      360.0     1913.0     True        False   41.0
# 403      360.0     1850.0     True        False   43.0
# 19       190.0     1099.0    False        False   48.0
# 238       65.0      827.0    False        False   47.0
# 487      360.0      715.0     True        False   46.0
# 142      360.0     2402.0     True        False   50.0
# 284      360.0     2861.0     True        False   49.0

# %% [markdown]
# Only ranked flares in the NASA table:

# %%
NASAtop50_df = (NASAtop50_df[NASAtop50_df["Match"].isnull() == False])
NASAtop50_df["region"] = NASAtop50_df["region"].astype("float") #allows matplotlib to treat region as a float for an ordered y

# %% [markdown]
# ___

# %% [markdown]
# ## Question 3: Analysis Plot

# %%
xray = NASAtop50_df["xray_importance"].map(lambda x: float(x[1:]))
#cmap takes away the xlabel for some reason
NASAtop50_df.plot.scatter(figsize=(20, 10), 
                          x="start_datetime", 
                          y="region",
                          c=xray, 
                          cmap="summer_r", 
                          #alpha = .8,
                          sharex=False,
                          s=xray*60)
# Out:
# <AxesSubplot:xlabel='start_datetime', ylabel='region'>

# %% [markdown]
# **We can deduce from this plot that large solar flares (dark green) tend to cluster with smaller solar flares in the same region.**

# %% [markdown]
# 1. A short description (2 sentences) of what the intent of your plot is (think in terms of our discussion and notebooks on how we show variation, co-variation in terms of summary statistics like central trend, spread, skew etc.),
# 2. code to produce your plot,
# 3. a short text description of your plot, and
# 4. a sentence or two of interpretation of your plot (again think of variation, co-variation, etc.).

# %% [markdown]
# ### Part 2: Pie plot showing proportion of Flare Halo CMEs in top 50 vs entire data set.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
df_types = [nasa_df, NASAtop50_df]
name = ["NASA", "Top 50 NASA"]
for ax, df,name in zip(axes,df_types,name):
    df["is_halo"].value_counts().plot.pie(ax=ax)
    is_halo_percentage = (df["is_halo"].value_counts()[1] / (df["is_halo"].value_counts()[1] + df["is_halo"].value_counts()[0])) * 100
    ax.set_title( "%s df percentage of flares with a halo: %d %%" %(name,is_halo_percentage))

# %% [markdown]
# **Flares in the top 50 rankings are more likely to have Flare Halo CMEs based on the data that we have collected.**
